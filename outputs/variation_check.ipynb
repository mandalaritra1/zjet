# %%
import pickle
import numpy as np


import pickle
filename = 'test_variation.pkl'
with open(filename, 'rb') as f:
    output = pickle.load(f)

# %%
output['response_matrix_g']
# Out:
# Hist(
#   StrCategory(['UL18NanoAODv9'], growth=True, name='dataset', label='Primary dataset'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptreco', label='p_{T,RECO} (GeV)'),
#   Variable([0, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100, 110, 13000], name='mreco', label='m_{RECO} (GeV)'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptgen', label='p_{T,GEN} (GeV)'),
#   Variable([0, 10, 20, 40, 60, 80, 100, 13000], name='mgen', label='Mass (GeV)'),
#   StrCategory(['nominal', 'JMRUp', 'JMRDown', 'JMSUp', 'JMSDown', 'JES_AbsoluteScaleUp', 'JES_AbsoluteScaleDown'], growth=True, name='systematic', label='Systematic Uncertainty'),
#   storage=Weight()) # Sum: WeightedSum(value=494.408, variance=4.05464) (WeightedSum(value=494.641, variance=4.05659) with flow)

# %%
import matplotlib.pyplot as plt
plt.plot(output['response_matrix_g'][{'systematic':'nominal'}].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(70, 35).sum(axis = 0))
# plt.plot(output['response_matrix_g'][{'systematic':'JMSUp'}].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(70, 35).sum(axis = 0))
# plt.plot(output['response_matrix_g'][{'systematic':'JMSDown'}].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(70, 35).sum(axis = 0))
# plt.plot(output['response_matrix_g'][{'systematic':'JES_AbsoluteScaleUp'}].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(70,35).sum(axis = 0))
# plt.plot(output['response_matrix_g'][{'systematic':'JES_AbsoluteScaleDown'}].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(70,35).sum(axis = 0))
plt.plot(output['ptjet_mjet_g_gen'][{'systematic':'nominal'}].project('ptgen', 'mgen').values().reshape(35))

# %%
plt.plot(output['ptjet_mjet_g_gen'][{'systematic':'nominal'}].project('ptgen', 'mgen').values().reshape(35))
plt.plot(output['ptjet_mjet_g_gen'][{'systematic':'JMSUp'}].project('ptgen', 'mgen').values().reshape(35))
plt.plot(output['ptjet_mjet_g_gen'][{'systematic':'JMSDown'}].project('ptgen', 'mgen').values().reshape(35))
plt.plot(output['ptjet_mjet_g_gen'][{'systematic':'JMRUp'}].project('ptgen', 'mgen').values().reshape(35))
plt.plot(output['ptjet_mjet_g_gen'][{'systematic':'JMRDown'}].project('ptgen', 'mgen').values().reshape(35))
plt.plot(output['ptjet_mjet_g_gen'][{'systematic':'JES_AbsoluteScaleDown'}].project('ptgen', 'mgen').values().reshape(35))
