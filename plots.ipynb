# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep

# %%
plt.style.use(hep.style.CMS)

# %%
with open("qjetmass_zjets_genUL16NanoAODv9.pkl", "rb") as f:
    output = pickle.load( f )

# %%
output['response_matrix_u']
# Out:
# Hist(
#   StrCategory(['UL16NanoAODv9'], growth=True, name='dataset', label='Primary dataset'),
#   Variable([200, 260, 350, 460, 550, 650, 760, 13000], name='ptreco', label='p_{T,RECO} (GeV)'),
#   Variable([0, 5, 10, 20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 1000], name='mreco', label='m_{RECO} (GeV)'),
#   Variable([200, 260, 350, 460, 550, 650, 760, 13000], name='ptgen', label='p_{T,RECO} (GeV)'),
#   Variable(array([   0. ,    2.5,    5. ,    7.5,   10. ,   15. ,   20. ,   30. ,
#          40. ,   50. ,   60. ,   70. ,   80. ,   90. ,  100. ,  125. ,
#         150. ,  175. ,  200. ,  225. ,  250. ,  275. ,  300. ,  325. ,
#         350. , 1000. ]), name='mgen', label='Mass [GeV]'),
#   StrCategory(['nominal', 'puUp', 'puDown', 'elerecoUp', 'elerecoDown', 'murecoUp', 'murecoDown', 'JES_up', 'JES_down', 'JER_up', 'JER_down'], growth=True, name='systematic', label='Systematic Uncertainty'),
# ...

# %%
output['response_matrix_u'][{"systematic": "nominal"}].project("ptreco").plot(density = False)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
h = output['response_matrix_u'].project("systematic","mreco")
filtered_hist = h[["nominal", "puUp", "puDown"], :]
filtered_hist.plot()
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 h = output['response_matrix_u'].project("systematic","mreco")
#       2 filtered_hist = h[["nominal", "puUp", "puDown"], :]
#       3 filtered_hist.plot()
#
# NameError: name 'output' is not defined

# %%
fig = plt.figure(figsize=(10, 8))
main_ax_artists, sublot_ax_arists = hist_1.plot_ratio(
    hist_2,
    rp_ylabel=r"Ratio",
    rp_num_label="hist1",
    rp_denom_label="hist2",
)

# %%
filtered_hist = h[["nominal", "elerecoUp", "elerecoDown"], :]
filtered_hist.plot()
plt.legend()
# Out:
# /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
filtered_hist = h[["nominal", "murecoUp", "murecoDown"], :]
filtered_hist.plot()
plt.legend()
# Out:
# /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
filtered_hist = h[["nominal", "JES_up","JES_down"], :]
filtered_hist.plot()
plt.legend()
# Out:
# /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
filtered_hist = h[["nominal", "JES_up","JES_down"], :]
filtered_hist.plot()
plt.legend()
# Out:
# /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
filtered_hist = h[["nominal", "JER_up","JER_down"], :]
filtered_hist.plot()
plt.legend()
# Out:
# /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
filtered_hist = h[["nominal", "murecoUp","murecoDown"], :]
filtered_hist.plot()
plt.legend()
# Out:
# /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
import tracemalloc

# %%
with open("qjetmass_zjets_gen.pkl", "rb") as f:
    output = pickle.load( f )
