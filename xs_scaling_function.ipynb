# %%
import pickle
import matplotlib.pyplot as plt
filename = 'outputs/updated_xs.pkl'
with open(filename, 'rb') as f:
    output = pickle.load(f)

# %%
import pickle
#filename = 'outputs/mc_weight.pkl'
filename ='outputs/mpt_mc_0104.pkl'
with open(filename, 'rb') as f:
    output = pickle.load(f)

# %%
output['fakes_u']['UL16NanoAODv9',...]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 output['fakes_u']['UL16NanoAODv9',...]
#
# File /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400, in BaseHist.__getitem__(self, index)
#     393 def __getitem__(  # type: ignore[override]
#     394     self, index: IndexingExpr
#     395 ) -> Self | float | bh.accumulators.Accumulator:
#     396     """
#     397     Get histogram item.
#     398     """
# --> 400     return super().__getitem__(self._index_transform(index))
#
# File /opt/conda/lib/python3.10/site-packages/boost_histogram/_internal/hist.py:812, in Histogram.__getitem__(self, index)
#     811 def __getitem__(self: H, index: IndexingExpr) -> H | float | Accumulator:
# --> 812     indexes = self._compute_commonindex(index)
#     814     # If this is (now) all integers, return the bin contents
# ...

# %%
output['pt_z_reco']['UL16NanoAODv9',:,'nominal'].plot()
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 output['pt_z_reco']['UL16NanoAODv9',:,'nominal'].plot()
#       2 plt.yscale('log')
#
# File /opt/conda/lib/python3.10/site-packages/hist/basehist.py:400, in BaseHist.__getitem__(self, index)
#     393 def __getitem__(  # type: ignore[override]
#     394     self, index: IndexingExpr
#     395 ) -> Self | float | bh.accumulators.Accumulator:
#     396     """
#     397     Get histogram item.
#     398     """
# --> 400     return super().__getitem__(self._index_transform(index))
#
# File /opt/conda/lib/python3.10/site-packages/boost_histogram/_internal/hist.py:812, in Histogram.__getitem__(self, index)
#     811 def __getitem__(self: H, index: IndexingExpr) -> H | float | Accumulator:
# --> 812     indexes = self._compute_commonindex(index)
# ...

# %%
era =  'UL16NanoAODv9'
sumw_dic = {}

sumw_dic[era] = {}
for ht_bin in output['cutflow'][era].keys():
    sumw_dic[era].update({ht_bin:output['cutflow'][era][ht_bin]['all events'] })

# %%
sumw_dic['UL16NanoAODv9']
# Out:
# {'DYJetsToLL_M-50_HT-100to200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 1484941,
#  'DYJetsToLL_M-50_HT-800to1200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 2393976,
#  'DYJetsToLL_M-50_HT-600to800_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 230249,
#  'DYJetsToLL_M-50_HT-2500toInf_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 37888,
#  'DYJetsToLL_M-50_HT-200to400_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 1121758,
#  'DYJetsToLL_M-50_HT-1200to2500_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 606142}

# %%
output['cutflow'].keys

sumw_dic = {}
for era in output['cutflow'].keys():
    sumw_dic[era] = {}
    for ht_bin in output['cutflow'][era].keys():
        sumw_dic[era].update({ht_bin:output['cutflow'][era][ht_bin]['sumw'] })

# %%
sumw_dic
# Out:
# {'UL16NanoAODv9': {'DYJetsToLL_M-50_HT-100to200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 1108295.2963256836,
#   'DYJetsToLL_M-50_HT-800to1200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 1548.0297764539719,
#   'DYJetsToLL_M-50_HT-600to800_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 6004.06706237793,
#   'DYJetsToLL_M-50_HT-2500toInf_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 4.707008833996952,
#   'DYJetsToLL_M-50_HT-400to600_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 17596.72917175293,
#   'DYJetsToLL_M-50_HT-200to400_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 239770.66442871094,
#   'DYJetsToLL_M-50_HT-1200to2500_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 634.6930387020111},
#  'UL18NanoAODv9': {'DYJetsToLL_M-50_HT-400to600_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 64610.03691482544,
#   'DYJetsToLL_M-50_HT-800to1200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 9349.124209403992,
# ...

# %%
nlo = 6077
((6077*19520)/(1023872.1899035056))*(139.2/6077)
# Out:
# 2.653831236744578

# %%
lumi = {'UL16NanoAODv9':19.52 , 'UL16NanoAODAPVv9': 16.81 ,'UL17NanoAODv9': 41.48 , 'UL18NanoAODv9': 59.83}

# %%
xsdb = {
    'DYJetsToLL_M-50_HT-100to200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 139.2,
    'DYJetsToLL_M-50_HT-1200to2500_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 0.1305,
    'DYJetsToLL_M-50_HT-200to400_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 38.4,
    'DYJetsToLL_M-50_HT-2500toInf_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 0.002997,
    'DYJetsToLL_M-50_HT-600to800_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 1.258,
    'DYJetsToLL_M-50_HT-400to600_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 5.174,
    'DYJetsToLL_M-50_HT-70to100_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 140.0	,
    'DYJetsToLL_M-50_HT-800to1200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 0.5598
}

# %%
324.725 +140.0
# Out:
# 464.725

# %%
## Total xs = 464.725

# %%
41480*139.2/(2469799.698852539
# Out:
#   Cell In[24], line 1
#     41480*139.2/(2469799.698852539
#                                   ^
# SyntaxError: incomplete input

# %%
xsweight_dic = {}
for era in output['cutflow'].keys():
    xsweight_dic[era] = {}
    for ht_bin in output['cutflow'][era].keys():
        xsweight_dic[era].update({ht_bin: (lumi[era]*xsdb[ht_bin]*1000)/sumw_dic[era][ht_bin] })

# %%
xsweight_dic
# Out:
# {'UL16NanoAODv9': {'DYJetsToLL_M-50_HT-100to200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 2.653831236744578,
#   'DYJetsToLL_M-50_HT-800to1200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 6.2720323669270615,
#   'DYJetsToLL_M-50_HT-400to600_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 6.547528243153286,
#   'DYJetsToLL_M-50_HT-600to800_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 4.692815676873025,
#   'DYJetsToLL_M-50_HT-2500toInf_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 14.990916178347208,
#   'DYJetsToLL_M-50_HT-1200to2500_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 4.5838080650591735,
#   'DYJetsToLL_M-50_HT-200to400_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 3.4705425527068288},
#  'UL18NanoAODv9': {'DYJetsToLL_M-50_HT-600to800_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 5.7959177900609005,
#   'DYJetsToLL_M-50_HT-800to1200_TuneCP5_PSweights_13TeV-madgraphMLM-pythia8': 3.916098407115151,
# ...

# %%
import pickle
filename = 'outputs/pythia_v25.pkl'
with open(filename, 'rb') as f:
    output = pickle.load(f)

# %%
output['response_matrix_u']
# Out:
# Hist(
#   StrCategory(['UL16NanoAODv9', 'UL17NanoAODv9', 'UL18NanoAODv9', 'UL16NanoAODAPVv9'], growth=True, name='dataset', label='Primary dataset'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptreco', label='p_{T,RECO} (GeV)'),
#   Variable([0, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100, 110, 13000], name='mreco', label='m_{RECO} (GeV)'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptgen', label='p_{T,GEN} (GeV)'),
#   Variable([0, 10, 20, 40, 60, 80, 100, 13000], name='mgen', label='Mass (GeV)'),
#   StrCategory(['nominal'], growth=True, name='systematic', label='Systematic Uncertainty'),
#   storage=Weight()) # Sum: WeightedSum(value=95582.7, variance=12448.4)

# %%
import pickle
filename = 'outputs/data_jet_veto.pkl'
with open(filename, 'rb') as f:
    output_data = pickle.load(f)

# %%
output['ptjet_mjet_g_reco'].project('ptreco')[1:4].plot(density = True)
output_data['ptjet_mjet_g_reco'].project('ptreco')[1:4].plot(density = True)
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f8924044970>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
output_data['ptjet_mjet_g_reco'].project('ptreco').values()/output['ptjet_mjet_g_reco'].project('ptreco').values()
# Out:
# /tmp/ipykernel_341/2647978659.py:1: RuntimeWarning: invalid value encountered in divide
#   output_data['ptjet_mjet_g_reco'].project('ptreco').values()/output['ptjet_mjet_g_reco'].project('ptreco').values()
# array([       nan, 1.30802111, 1.35152738, 1.39967612, 1.34832439])

# %%
h = output['response_matrix_g']

# %%
sf = [       1, 1.30802111, 1.35152738, 1.39967612, 1.34832439]
h_modified = h.project('ptreco', 'mreco')
for i in range(5):
    h_modified.view(flow = True)[i]*= sf[i]

# %%
h_modified.project('ptreco')[1:4].plot()
output_data['ptjet_mjet_g_reco'].project('ptreco')[1:4].plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f892605d9c0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
h_modified.project('ptreco', 'mreco')[3, :13].plot()
output_data['ptjet_mjet_g_reco'].project('ptreco', 'mreco')[3, :13].plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f89261fd330>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
import hist
import matplotlib.pyplot as plt
for i in range(4):
    output['ptjet_mjet_u_reco'].project('dataset','ptreco', 'mreco')[i:i+1,4, :].plot()
    #output_data['ptjet_mjet_u_reco'].project('dataset','ptreco', 'mreco')[i:i+1,4, :].plot()
    plt.legend()
    plt.xlim(0,300)
    plt.show()

# %%
import hist
import matplotlib.pyplot as plt
plt.figure(figsize = (6,6))
for i in range(4):
    output['response_matrix_g'].project('dataset','ptgen', 'mgen')[i:i+1,1, :10].plot()
    #output['response_matrix_g'].project('dataset','ptgen', 'mgen')[i:i+1,1, :].plot()
    #plt.xlim(0,6000)
    plt.legend()

    plt.show()

# %%
import numpy as np
plt.imshow(np.log(output['response_matrix_u'].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(120,60)), vmin = 0, aspect = 0.5, origin='lower')
# Out:
# /tmp/ipykernel_341/86943895.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(output['response_matrix_u'].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(120,60)), vmin = 0, aspect = 0.5, origin='lower')

# %%
import numpy as np
plt.imshow(np.log(output['response_matrix_g'].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(120,60)), vmin = 0, aspect = 0.5, origin='lower')
# Out:
# /tmp/ipykernel_341/3224034380.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(output['response_matrix_g'].project('ptreco', 'mreco', 'ptgen', 'mgen').values().reshape(120,60)), vmin = 0, aspect = 0.5, origin='lower')

# %%
import pickle
filename = 'outputs/herwig_v25.pkl'
with open(filename, 'rb') as f:
    output = pickle.load(f)

# %%
output['cutflow']
# Out:
# {'UL16NanoAODv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': defaultdict(int,
#               {'sumw': 158089145.5,
#                'all events': 18992599,
#                'weights cut': 18321358,
#                'npv': 18321334,
#                'oneGenJet': 195868,
#                'matches': 36617924,
#                'misses': 12396,
#                'twoGen_ee': 1879868,
#                'twoGen_mm': 1882283,
#                'twoGen_leptons': 3762151,
#                'z_ptcut_gen': 173830,
#                'z_mcut_gen': 3638045,
#                'z_jet_dphi_sel_gen': 122553,
#                'z_pt_asym_sel_gen': 84842,
#                'kinsel_gen': 49623,
#                'toposel_gen': 50273,
#                'allsel_gen': 29385,
#                'twoReco_ee': 1231280,
#                'twoReco_mm': 1905660,
#                'twoReco_leptons': 3136940,
#                'z_ptcut_reco': 108388,
#                'z_mcut_reco': 3023339,
# ...

# %%
output['cutflow'].keys

sumw_dic = {}
for era in output['cutflow'].keys():
    sumw_dic[era] = {}
    for ht_bin in output['cutflow'][era].keys():
        sumw_dic[era].update({ht_bin:output['cutflow'][era][ht_bin]['all events'] })

# %%
sumw_dic
# Out:
# {'UL16NanoAODv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 18992599},
#  'UL18NanoAODv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 24369608},
#  'UL17NanoAODv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 16221707},
#  'UL16NanoAODAPVv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 29539012}}

# %%
5.036
# Out:
# 5.036

# %%
xsweight_dic = {}
for era in output['cutflow'].keys():
    xsweight_dic[era] = {}
    for ht_bin in output['cutflow'][era].keys():
        xsweight_dic[era].update({ht_bin: (lumi[era]*320*1000)/sumw_dic[era][ht_bin] })

# %%
xsweight_dic
# Out:
# {'UL16NanoAODv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 0.328886004490486},
#  'UL18NanoAODv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 0.7856343031861653},
#  'UL17NanoAODv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 0.818261604651101},
#  'UL16NanoAODAPVv9': {'DYJetsToLL_M-50_TuneCH3_13TeV-madgraphMLM-herwig7': 0.18210493973190436}}

# %%
0.32*output['response_matrix_g']['UL16NanoAODv9',...]
# Out:
# Hist(
#   Variable([140, 200, 260, 350, 460, 13000], name='ptreco', label='p_{T,RECO} (GeV)'),
#   Variable([0, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100, 110, 13000], name='mreco', label='m_{RECO} (GeV)'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptgen', label='p_{T,GEN} (GeV)'),
#   Variable([0, 10, 20, 40, 60, 80, 100, 13000], name='mgen', label='Mass (GeV)'),
#   StrCategory(['herwig'], growth=True, name='systematic', label='Systematic Uncertainty'),
#   storage=Weight()) # Sum: WeightedSum(value=18921.1, variance=53259.2) (WeightedSum(value=18923, variance=53262.8) with flow)

# %%
0.78*output['response_matrix_g']['UL17NanoAODv9',...]
# Out:
# Hist(
#   Variable([140, 200, 260, 350, 460, 13000], name='ptreco', label='p_{T,RECO} (GeV)'),
#   Variable([0, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100, 110, 13000], name='mreco', label='m_{RECO} (GeV)'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptgen', label='p_{T,GEN} (GeV)'),
#   Variable([0, 10, 20, 40, 60, 80, 100, 13000], name='mgen', label='Mass (GeV)'),
#   StrCategory(['herwig'], growth=True, name='systematic', label='Systematic Uncertainty'),
#   storage=Weight()) # Sum: WeightedSum(value=34675.8, variance=190899) (WeightedSum(value=34690.4, variance=190970) with flow)

# %%
0.81*output['response_matrix_g']['UL18NanoAODv9',...]
# Out:
# Hist(
#   Variable([140, 200, 260, 350, 460, 13000], name='ptreco', label='p_{T,RECO} (GeV)'),
#   Variable([0, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100, 110, 13000], name='mreco', label='m_{RECO} (GeV)'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptgen', label='p_{T,GEN} (GeV)'),
#   Variable([0, 10, 20, 40, 60, 80, 100, 13000], name='mgen', label='Mass (GeV)'),
#   StrCategory(['herwig'], growth=True, name='systematic', label='Systematic Uncertainty'),
#   storage=Weight()) # Sum: WeightedSum(value=54237.4, variance=319984) (WeightedSum(value=54255.6, variance=320095) with flow)

# %%
0.18*output['response_matrix_g']['UL16NanoAODAPVv9',...]
# Out:
# Hist(
#   Variable([140, 200, 260, 350, 460, 13000], name='ptreco', label='p_{T,RECO} (GeV)'),
#   Variable([0, 5, 10, 15, 20, 30, 40, 50, 60, 70, 80, 90, 100, 110, 13000], name='mreco', label='m_{RECO} (GeV)'),
#   Variable([140, 200, 260, 350, 460, 13000], name='ptgen', label='p_{T,GEN} (GeV)'),
#   Variable([0, 10, 20, 40, 60, 80, 100, 13000], name='mgen', label='Mass (GeV)'),
#   StrCategory(['herwig'], growth=True, name='systematic', label='Systematic Uncertainty'),
#   storage=Weight()) # Sum: WeightedSum(value=15913.5, variance=22713) (WeightedSum(value=15916.4, variance=22717.5) with flow)
